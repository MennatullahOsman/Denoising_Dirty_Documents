# %% [markdown]
# <a href="https://colab.research.google.com/github/MennatullahOsman/Denoising_Dirty_Documents/blob/main/Model_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount = True)
# Out:
# Mounted at /content/drive

# %%
from tensorflow.keras.layers import Conv2D,MaxPooling2D,UpSampling2D
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from keras.optimizers import SGD
import matplotlib.pyplot as plt
import tensorflow as tf
import pickle
import os

# %%
os.chdir('/content/drive/My Drive/denoising-dirty-documents/pickle_data')

pickle_out = open("x_train.pickle", "rb")
x_train = pickle.load(pickle_out)
pickle_out.close()

pickle_out = open("y_train.pickle", "rb") 
y_train = pickle.load(pickle_out)
pickle_out.close()

pickle_out = open("x_val.pickle", "rb")
x_val = pickle.load(pickle_out)
pickle_out.close()

pickle_out = open("y_val.pickle", "rb")
y_val = pickle.load(pickle_out)
pickle_out.close()

pickle_out = open("test.pickle", "rb")
test = pickle.load(pickle_out)
pickle_out.close()

# %%
tf.keras.backend.clear_session()

input_layer = tf.keras.Input(shape=(420, 540, 1))

#Encoder
x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_layer) 
x = MaxPooling2D((2, 2), padding='same')(x)

#Decoder
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x) 
x = UpSampling2D((2, 2))(x)

output_layer = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

AutoEncoder = tf.keras.Model(input_layer, output_layer)

opt = SGD(lr=1e-2 ,momentum = 0.9 , decay  = 1e-2/100)

AutoEncoder.compile(optimizer=opt, loss='mse', metrics ='accuracy')

AutoEncoder.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 420, 540, 1)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 420, 540, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 210, 270, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 210, 270, 32)      9248
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 420, 540, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 420, 540, 1)       289
# =================================================================
# Total params: 9,857
# Trainable params: 9,857
# Non-trainable params: 0
# _________________________________________________________________

# %%
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20)
Model_1 = AutoEncoder.fit(x_train , y_train ,epochs=100, batch_size=8,validation_data=(x_val,y_val),  callbacks=[earlystop])
# Out:
# Epoch 1/100
# 13/13 [==============================] - 1s 97ms/step - loss: 0.1480 - accuracy: 0.6497 - val_loss: 0.0706 - val_accuracy: 0.6411
# Epoch 2/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0667 - accuracy: 0.6509 - val_loss: 0.0705 - val_accuracy: 0.6411
# Epoch 3/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0694 - accuracy: 0.6509 - val_loss: 0.0692 - val_accuracy: 0.6411
# Epoch 4/100
# 13/13 [==============================] - 1s 67ms/step - loss: 0.0662 - accuracy: 0.6509 - val_loss: 0.0652 - val_accuracy: 0.6411
# Epoch 5/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0636 - accuracy: 0.6509 - val_loss: 0.0644 - val_accuracy: 0.6411
# Epoch 6/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0634 - accuracy: 0.6509 - val_loss: 0.0640 - val_accuracy: 0.6411
# Epoch 7/100
# 13/13 [==============================] - 1s 67ms/step - loss: 0.0629 - accuracy: 0.6509 - val_loss: 0.0636 - val_accuracy: 0.6411
# Epoch 8/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0626 - accuracy: 0.6509 - val_loss: 0.0633 - val_accuracy: 0.6411
# Epoch 9/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0622 - accuracy: 0.6509 - val_loss: 0.0629 - val_accuracy: 0.6411
# Epoch 10/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0619 - accuracy: 0.6509 - val_loss: 0.0625 - val_accuracy: 0.6411
# Epoch 11/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0615 - accuracy: 0.6509 - val_loss: 0.0622 - val_accuracy: 0.6411
# Epoch 12/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0611 - accuracy: 0.6509 - val_loss: 0.0617 - val_accuracy: 0.6411
# Epoch 13/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0607 - accuracy: 0.6509 - val_loss: 0.0613 - val_accuracy: 0.6411
# Epoch 14/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0603 - accuracy: 0.6509 - val_loss: 0.0608 - val_accuracy: 0.6411
# Epoch 15/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0599 - accuracy: 0.6509 - val_loss: 0.0604 - val_accuracy: 0.6411
# Epoch 16/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0594 - accuracy: 0.6509 - val_loss: 0.0599 - val_accuracy: 0.6411
# Epoch 17/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0589 - accuracy: 0.6509 - val_loss: 0.0594 - val_accuracy: 0.6411
# Epoch 18/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0584 - accuracy: 0.6509 - val_loss: 0.0588 - val_accuracy: 0.6411
# Epoch 19/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0578 - accuracy: 0.6509 - val_loss: 0.0582 - val_accuracy: 0.6411
# Epoch 20/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0572 - accuracy: 0.6509 - val_loss: 0.0575 - val_accuracy: 0.6411
# Epoch 21/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0565 - accuracy: 0.6509 - val_loss: 0.0568 - val_accuracy: 0.6411
# Epoch 22/100
# 13/13 [==============================] - 1s 71ms/step - loss: 0.0558 - accuracy: 0.6509 - val_loss: 0.0559 - val_accuracy: 0.6411
# Epoch 23/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0549 - accuracy: 0.6509 - val_loss: 0.0550 - val_accuracy: 0.6411
# Epoch 24/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0540 - accuracy: 0.6509 - val_loss: 0.0539 - val_accuracy: 0.6411
# Epoch 25/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0529 - accuracy: 0.6509 - val_loss: 0.0528 - val_accuracy: 0.6411
# Epoch 26/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0518 - accuracy: 0.6509 - val_loss: 0.0516 - val_accuracy: 0.6411
# Epoch 27/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0506 - accuracy: 0.6509 - val_loss: 0.0503 - val_accuracy: 0.6411
# Epoch 28/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0493 - accuracy: 0.6509 - val_loss: 0.0489 - val_accuracy: 0.6411
# Epoch 29/100
# 13/13 [==============================] - 1s 71ms/step - loss: 0.0479 - accuracy: 0.6510 - val_loss: 0.0475 - val_accuracy: 0.6413
# Epoch 30/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0464 - accuracy: 0.6512 - val_loss: 0.0459 - val_accuracy: 0.6417
# Epoch 31/100
# 13/13 [==============================] - 1s 71ms/step - loss: 0.0448 - accuracy: 0.6516 - val_loss: 0.0442 - val_accuracy: 0.6424
# Epoch 32/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0432 - accuracy: 0.6523 - val_loss: 0.0424 - val_accuracy: 0.6430
# Epoch 33/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0414 - accuracy: 0.6532 - val_loss: 0.0405 - val_accuracy: 0.6440
# Epoch 34/100
# 13/13 [==============================] - 1s 71ms/step - loss: 0.0395 - accuracy: 0.6543 - val_loss: 0.0385 - val_accuracy: 0.6452
# Epoch 35/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0376 - accuracy: 0.6555 - val_loss: 0.0365 - val_accuracy: 0.6467
# Epoch 36/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0357 - accuracy: 0.6567 - val_loss: 0.0346 - val_accuracy: 0.6482
# Epoch 37/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0338 - accuracy: 0.6581 - val_loss: 0.0327 - val_accuracy: 0.6494
# Epoch 38/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0321 - accuracy: 0.6593 - val_loss: 0.0309 - val_accuracy: 0.6508
# Epoch 39/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0304 - accuracy: 0.6605 - val_loss: 0.0293 - val_accuracy: 0.6516
# Epoch 40/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0289 - accuracy: 0.6613 - val_loss: 0.0279 - val_accuracy: 0.6528
# Epoch 41/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0276 - accuracy: 0.6622 - val_loss: 0.0266 - val_accuracy: 0.6533
# Epoch 42/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0264 - accuracy: 0.6629 - val_loss: 0.0255 - val_accuracy: 0.6538
# Epoch 43/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0254 - accuracy: 0.6634 - val_loss: 0.0245 - val_accuracy: 0.6544
# Epoch 44/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0245 - accuracy: 0.6637 - val_loss: 0.0237 - val_accuracy: 0.6548
# Epoch 45/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0238 - accuracy: 0.6641 - val_loss: 0.0230 - val_accuracy: 0.6551
# Epoch 46/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0231 - accuracy: 0.6644 - val_loss: 0.0224 - val_accuracy: 0.6553
# Epoch 47/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0226 - accuracy: 0.6646 - val_loss: 0.0218 - val_accuracy: 0.6557
# Epoch 48/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0221 - accuracy: 0.6649 - val_loss: 0.0213 - val_accuracy: 0.6557
# Epoch 49/100
# 13/13 [==============================] - 1s 77ms/step - loss: 0.0216 - accuracy: 0.6651 - val_loss: 0.0209 - val_accuracy: 0.6560
# Epoch 50/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0213 - accuracy: 0.6653 - val_loss: 0.0205 - val_accuracy: 0.6562
# Epoch 51/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0209 - accuracy: 0.6656 - val_loss: 0.0202 - val_accuracy: 0.6562
# Epoch 52/100
# 13/13 [==============================] - 1s 71ms/step - loss: 0.0206 - accuracy: 0.6654 - val_loss: 0.0199 - val_accuracy: 0.6567
# Epoch 53/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0202 - accuracy: 0.6660 - val_loss: 0.0195 - val_accuracy: 0.6565
# Epoch 54/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0199 - accuracy: 0.6659 - val_loss: 0.0192 - val_accuracy: 0.6568
# Epoch 55/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0196 - accuracy: 0.6661 - val_loss: 0.0190 - val_accuracy: 0.6571
# Epoch 56/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0194 - accuracy: 0.6664 - val_loss: 0.0187 - val_accuracy: 0.6568
# Epoch 57/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0191 - accuracy: 0.6663 - val_loss: 0.0185 - val_accuracy: 0.6574
# Epoch 58/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0188 - accuracy: 0.6667 - val_loss: 0.0182 - val_accuracy: 0.6572
# Epoch 59/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0186 - accuracy: 0.6666 - val_loss: 0.0179 - val_accuracy: 0.6576
# Epoch 60/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0183 - accuracy: 0.6669 - val_loss: 0.0177 - val_accuracy: 0.6576
# Epoch 61/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0181 - accuracy: 0.6670 - val_loss: 0.0174 - val_accuracy: 0.6578
# Epoch 62/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0179 - accuracy: 0.6672 - val_loss: 0.0172 - val_accuracy: 0.6578
# Epoch 63/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0177 - accuracy: 0.6672 - val_loss: 0.0170 - val_accuracy: 0.6581
# Epoch 64/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0174 - accuracy: 0.6675 - val_loss: 0.0168 - val_accuracy: 0.6580
# Epoch 65/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0172 - accuracy: 0.6676 - val_loss: 0.0166 - val_accuracy: 0.6582
# Epoch 66/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0170 - accuracy: 0.6676 - val_loss: 0.0164 - val_accuracy: 0.6584
# Epoch 67/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0169 - accuracy: 0.6679 - val_loss: 0.0162 - val_accuracy: 0.6584
# Epoch 68/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0166 - accuracy: 0.6679 - val_loss: 0.0160 - val_accuracy: 0.6586
# Epoch 69/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0165 - accuracy: 0.6681 - val_loss: 0.0158 - val_accuracy: 0.6586
# Epoch 70/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0163 - accuracy: 0.6681 - val_loss: 0.0157 - val_accuracy: 0.6587
# Epoch 71/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0161 - accuracy: 0.6682 - val_loss: 0.0155 - val_accuracy: 0.6588
# Epoch 72/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0159 - accuracy: 0.6684 - val_loss: 0.0153 - val_accuracy: 0.6588
# Epoch 73/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0158 - accuracy: 0.6685 - val_loss: 0.0152 - val_accuracy: 0.6590
# Epoch 74/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0156 - accuracy: 0.6685 - val_loss: 0.0150 - val_accuracy: 0.6591
# Epoch 75/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0155 - accuracy: 0.6687 - val_loss: 0.0149 - val_accuracy: 0.6591
# Epoch 76/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0153 - accuracy: 0.6688 - val_loss: 0.0147 - val_accuracy: 0.6591
# Epoch 77/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0152 - accuracy: 0.6688 - val_loss: 0.0146 - val_accuracy: 0.6593
# Epoch 78/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0150 - accuracy: 0.6689 - val_loss: 0.0144 - val_accuracy: 0.6593
# Epoch 79/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0149 - accuracy: 0.6690 - val_loss: 0.0143 - val_accuracy: 0.6594
# Epoch 80/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0147 - accuracy: 0.6691 - val_loss: 0.0142 - val_accuracy: 0.6594
# Epoch 81/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0146 - accuracy: 0.6692 - val_loss: 0.0140 - val_accuracy: 0.6596
# Epoch 82/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0145 - accuracy: 0.6692 - val_loss: 0.0139 - val_accuracy: 0.6596
# Epoch 83/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0143 - accuracy: 0.6694 - val_loss: 0.0138 - val_accuracy: 0.6596
# Epoch 84/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0142 - accuracy: 0.6693 - val_loss: 0.0137 - val_accuracy: 0.6597
# Epoch 85/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0141 - accuracy: 0.6695 - val_loss: 0.0136 - val_accuracy: 0.6597
# Epoch 86/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0140 - accuracy: 0.6695 - val_loss: 0.0135 - val_accuracy: 0.6599
# Epoch 87/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0139 - accuracy: 0.6696 - val_loss: 0.0133 - val_accuracy: 0.6599
# Epoch 88/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0137 - accuracy: 0.6697 - val_loss: 0.0132 - val_accuracy: 0.6599
# Epoch 89/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0136 - accuracy: 0.6697 - val_loss: 0.0131 - val_accuracy: 0.6599
# Epoch 90/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0135 - accuracy: 0.6698 - val_loss: 0.0130 - val_accuracy: 0.6600
# Epoch 91/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0134 - accuracy: 0.6698 - val_loss: 0.0129 - val_accuracy: 0.6601
# Epoch 92/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0133 - accuracy: 0.6699 - val_loss: 0.0128 - val_accuracy: 0.6601
# Epoch 93/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0132 - accuracy: 0.6699 - val_loss: 0.0127 - val_accuracy: 0.6601
# Epoch 94/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0131 - accuracy: 0.6700 - val_loss: 0.0126 - val_accuracy: 0.6602
# Epoch 95/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0130 - accuracy: 0.6700 - val_loss: 0.0125 - val_accuracy: 0.6602
# Epoch 96/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0129 - accuracy: 0.6701 - val_loss: 0.0124 - val_accuracy: 0.6603
# Epoch 97/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0128 - accuracy: 0.6701 - val_loss: 0.0123 - val_accuracy: 0.6603
# Epoch 98/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0128 - accuracy: 0.6702 - val_loss: 0.0123 - val_accuracy: 0.6603
# Epoch 99/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0127 - accuracy: 0.6702 - val_loss: 0.0122 - val_accuracy: 0.6604
# Epoch 100/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0126 - accuracy: 0.6703 - val_loss: 0.0121 - val_accuracy: 0.6604

# %%
# Check how loss & mae went down
epoch_loss = Model_1.history['loss']
epoch_val_loss = Model_1.history['val_loss']
epoch_accuracy = Model_1.history['accuracy']
epoch_val_accuracy = Model_1.history['val_accuracy']

plt.figure(figsize=(20,6))
plt.subplot(1,2,1)
plt.plot(range(0,len(epoch_loss)), epoch_loss, 'b-', linewidth=2, label='Train Loss')
plt.plot(range(0,len(epoch_val_loss)), epoch_val_loss, 'r-', linewidth=2, label='Val Loss')
plt.title('Evolution of loss on train & validation datasets over epochs')
plt.legend(loc='best')
plt.subplot(1,2,2)
plt.plot(range(0,len(epoch_accuracy)), epoch_accuracy, 'g-', linewidth=2, label='Train accuracy')
plt.plot(range(0,len(epoch_val_accuracy)), epoch_val_accuracy, 'y-', linewidth=2, label='Val accuracy')
plt.title('Evolution of accuracy on train & validation datasets over epochs')
plt.legend(loc='best')


plt.show()

# %%
output_test = AutoEncoder.predict(test, batch_size=16)

# %%
plt.figure(figsize=(15,25))
for i in range(0,8,2):
    plt.subplot(4,2,i+1)
    plt.imshow(test[i][:,:,0], cmap='gray')
    
    plt.subplot(4,2,i+2)
    plt.imshow(output_test[i][:,:,0], cmap='gray')

plt.show()
