# %% [markdown]
# <a href="https://colab.research.google.com/github/MennatullahOsman/Denoising_Dirty_Documents/blob/main/Model_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount = True)
# Out:
# Mounted at /content/drive

# %%
from tensorflow.keras.layers import Conv2D,MaxPooling2D,UpSampling2D
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from keras.optimizers import SGD
import matplotlib.pyplot as plt
import tensorflow as tf
import pickle
import os

# %%
os.chdir('/content/drive/My Drive/denoising-dirty-documents/pickle_data')

pickle_out = open("x_train_aug.pickle", "rb")
x_train_aug = pickle.load(pickle_out)
pickle_out.close()

pickle_out = open("y_train_aug.pickle", "rb") 
y_train_aug = pickle.load(pickle_out)
pickle_out.close()

pickle_out = open("x_val.pickle", "rb")
x_val = pickle.load(pickle_out)
pickle_out.close()

pickle_out = open("y_val.pickle", "rb")
y_val = pickle.load(pickle_out)
pickle_out.close()

pickle_out = open("test.pickle", "rb")
test = pickle.load(pickle_out)
pickle_out.close()

# %%
tf.keras.backend.clear_session()

input_layer = tf.keras.Input(shape=(420, 540, 1))

#Encoder
x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_layer) 
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x) 
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x) 
x = MaxPooling2D((2, 2), padding='same')(x)

#Decoder
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x) 
x = UpSampling2D((2, 2))(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x) 
x = UpSampling2D((2, 2))(x)
x = Conv2D(32, (3, 3), activation='relu')(x) 
x = UpSampling2D((2, 2))(x)

output_layer = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

AutoEncoder = tf.keras.Model(input_layer, output_layer)

AutoEncoder.compile(optimizer='adam', loss='mse', metrics ='accuracy')

AutoEncoder.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 420, 540, 1)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 420, 540, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 210, 270, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 210, 270, 32)      9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 105, 135, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 105, 135, 32)      9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 53, 68, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 53, 68, 32)        9248
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 106, 136, 32)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 106, 136, 32)      9248
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 212, 272, 32)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 210, 270, 32)      9248
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 420, 540, 32)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 420, 540, 1)       289
# =================================================================
# Total params: 46,849
# Trainable params: 46,849
# Non-trainable params: 0
# _________________________________________________________________

# %%
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20)
Model_4 = AutoEncoder.fit(x_train_aug , y_train_aug ,epochs= 100, batch_size=30,validation_data=(x_val,y_val),  callbacks=[earlystop])
# Out:
# Epoch 1/100
# 54/54 [==============================] - 17s 317ms/step - loss: 0.0711 - accuracy: 0.5321 - val_loss: 0.0592 - val_accuracy: 0.6345
# Epoch 2/100
# 54/54 [==============================] - 16s 294ms/step - loss: 0.0392 - accuracy: 0.5512 - val_loss: 0.0512 - val_accuracy: 0.6410
# Epoch 3/100
# 54/54 [==============================] - 16s 298ms/step - loss: 0.0361 - accuracy: 0.5515 - val_loss: 0.0491 - val_accuracy: 0.6410
# Epoch 4/100
# 54/54 [==============================] - 16s 300ms/step - loss: 0.0335 - accuracy: 0.5516 - val_loss: 0.0472 - val_accuracy: 0.6411
# Epoch 5/100
# 54/54 [==============================] - 16s 300ms/step - loss: 0.0318 - accuracy: 0.5517 - val_loss: 0.0462 - val_accuracy: 0.6410
# Epoch 6/100
# 54/54 [==============================] - 16s 298ms/step - loss: 0.0304 - accuracy: 0.5518 - val_loss: 0.0448 - val_accuracy: 0.6417
# Epoch 7/100
# 54/54 [==============================] - 16s 297ms/step - loss: 0.0293 - accuracy: 0.5519 - val_loss: 0.0434 - val_accuracy: 0.6422
# Epoch 8/100
# 54/54 [==============================] - 16s 301ms/step - loss: 0.0282 - accuracy: 0.5520 - val_loss: 0.0423 - val_accuracy: 0.6427
# Epoch 9/100
# 54/54 [==============================] - 16s 300ms/step - loss: 0.0273 - accuracy: 0.5522 - val_loss: 0.0415 - val_accuracy: 0.6430
# Epoch 10/100
# 54/54 [==============================] - 16s 300ms/step - loss: 0.0264 - accuracy: 0.5523 - val_loss: 0.0407 - val_accuracy: 0.6434
# Epoch 11/100
# 54/54 [==============================] - 16s 299ms/step - loss: 0.0261 - accuracy: 0.5524 - val_loss: 0.0401 - val_accuracy: 0.6439
# Epoch 12/100
# 54/54 [==============================] - 16s 300ms/step - loss: 0.0250 - accuracy: 0.5526 - val_loss: 0.0384 - val_accuracy: 0.6449
# Epoch 13/100
# 54/54 [==============================] - 16s 299ms/step - loss: 0.0242 - accuracy: 0.5529 - val_loss: 0.0357 - val_accuracy: 0.6465
# Epoch 14/100
# 54/54 [==============================] - 16s 301ms/step - loss: 0.0225 - accuracy: 0.5534 - val_loss: 0.0329 - val_accuracy: 0.6485
# Epoch 15/100
# 54/54 [==============================] - 16s 300ms/step - loss: 0.0214 - accuracy: 0.5538 - val_loss: 0.0332 - val_accuracy: 0.6481
# Epoch 16/100
# 54/54 [==============================] - 16s 300ms/step - loss: 0.0209 - accuracy: 0.5540 - val_loss: 0.0301 - val_accuracy: 0.6503
# Epoch 17/100
# 54/54 [==============================] - 16s 300ms/step - loss: 0.0200 - accuracy: 0.5542 - val_loss: 0.0292 - val_accuracy: 0.6508
# Epoch 18/100
# 54/54 [==============================] - 16s 299ms/step - loss: 0.0194 - accuracy: 0.5543 - val_loss: 0.0284 - val_accuracy: 0.6515
# Epoch 19/100
# 54/54 [==============================] - 16s 299ms/step - loss: 0.0189 - accuracy: 0.5544 - val_loss: 0.0275 - val_accuracy: 0.6519
# Epoch 20/100
# 54/54 [==============================] - 16s 299ms/step - loss: 0.0183 - accuracy: 0.5546 - val_loss: 0.0265 - val_accuracy: 0.6526
# Epoch 21/100
# 54/54 [==============================] - 16s 300ms/step - loss: 0.0179 - accuracy: 0.5547 - val_loss: 0.0263 - val_accuracy: 0.6530
# Epoch 22/100
# 54/54 [==============================] - 16s 301ms/step - loss: 0.0174 - accuracy: 0.5548 - val_loss: 0.0254 - val_accuracy: 0.6534
# Epoch 23/100
# 54/54 [==============================] - 16s 301ms/step - loss: 0.0170 - accuracy: 0.5549 - val_loss: 0.0260 - val_accuracy: 0.6532
# Epoch 24/100
# 54/54 [==============================] - 16s 298ms/step - loss: 0.0168 - accuracy: 0.5549 - val_loss: 0.0243 - val_accuracy: 0.6541
# Epoch 25/100
# 54/54 [==============================] - 16s 299ms/step - loss: 0.0163 - accuracy: 0.5551 - val_loss: 0.0239 - val_accuracy: 0.6544
# 54/54 [==============================] - 16s 299ms/step - loss: 0.0098 - accuracy: 0.5563 - val_loss: 0.0160 - val_accuracy: 0.6589
# Epoch 68/100
# 54/54 [==============================] - 16s 300ms/step - loss: 0.0098 - accuracy: 0.5563 - val_loss: 0.0158 - val_accuracy: 0.6590
# Epoch 69/100
# 54/54 [==============================] - 16s 299ms/step - loss: 0.0097 - accuracy: 0.5563 - val_loss: 0.0157 - val_accuracy: 0.6589
# Epoch 70/100
# 54/54 [==============================] - 16s 298ms/step - loss: 0.0097 - accuracy: 0.5563 - val_loss: 0.0158 - val_accuracy: 0.6589
# Epoch 71/100
# 54/54 [==============================] - 16s 300ms/step - loss: 0.0095 - accuracy: 0.5563 - val_loss: 0.0156 - val_accuracy: 0.6590
# Epoch 72/100
# 54/54 [==============================] - 16s 300ms/step - loss: 0.0095 - accuracy: 0.5564 - val_loss: 0.0155 - val_accuracy: 0.6590
# Epoch 73/100
# 54/54 [==============================] - 16s 300ms/step - loss: 0.0095 - accuracy: 0.5564 - val_loss: 0.0157 - val_accuracy: 0.6591
# Epoch 74/100
# 54/54 [==============================] - 16s 301ms/step - loss: 0.0094 - accuracy: 0.5564 - val_loss: 0.0153 - val_accuracy: 0.6592
# Epoch 75/100
# 54/54 [==============================] - 16s 301ms/step - loss: 0.0093 - accuracy: 0.5564 - val_loss: 0.0152 - val_accuracy: 0.6592
# Epoch 76/100
# 54/54 [==============================] - 16s 299ms/step - loss: 0.0093 - accuracy: 0.5564 - val_loss: 0.0154 - val_accuracy: 0.6590
# Epoch 77/100
# 54/54 [==============================] - 16s 298ms/step - loss: 0.0093 - accuracy: 0.5564 - val_loss: 0.0151 - val_accuracy: 0.6592
# Epoch 78/100
# 54/54 [==============================] - 16s 299ms/step - loss: 0.0091 - accuracy: 0.5564 - val_loss: 0.0150 - val_accuracy: 0.6593
# Epoch 79/100
# 54/54 [==============================] - 16s 301ms/step - loss: 0.0091 - accuracy: 0.5564 - val_loss: 0.0150 - val_accuracy: 0.6593
# Epoch 80/100
# 54/54 [==============================] - 16s 300ms/step - loss: 0.0091 - accuracy: 0.5564 - val_loss: 0.0148 - val_accuracy: 0.6594
# Epoch 81/100
# 54/54 [==============================] - 16s 301ms/step - loss: 0.0091 - accuracy: 0.5564 - val_loss: 0.0152 - val_accuracy: 0.6592
# Epoch 82/100
# 54/54 [==============================] - 16s 300ms/step - loss: 0.0090 - accuracy: 0.5564 - val_loss: 0.0149 - val_accuracy: 0.6593
# Epoch 83/100
# 54/54 [==============================] - 16s 300ms/step - loss: 0.0090 - accuracy: 0.5564 - val_loss: 0.0147 - val_accuracy: 0.6595
# Epoch 84/100
# 54/54 [==============================] - 16s 298ms/step - loss: 0.0088 - accuracy: 0.5565 - val_loss: 0.0146 - val_accuracy: 0.6595
# Epoch 85/100
# 54/54 [==============================] - 16s 301ms/step - loss: 0.0088 - accuracy: 0.5565 - val_loss: 0.0149 - val_accuracy: 0.6594
# Epoch 86/100
# 54/54 [==============================] - 16s 302ms/step - loss: 0.0088 - accuracy: 0.5565 - val_loss: 0.0145 - val_accuracy: 0.6595
# Epoch 87/100
# 54/54 [==============================] - 16s 300ms/step - loss: 0.0087 - accuracy: 0.5565 - val_loss: 0.0148 - val_accuracy: 0.6595
# Epoch 88/100
# 54/54 [==============================] - 16s 299ms/step - loss: 0.0087 - accuracy: 0.5565 - val_loss: 0.0144 - val_accuracy: 0.6596
# Epoch 89/100
# 54/54 [==============================] - 16s 300ms/step - loss: 0.0086 - accuracy: 0.5565 - val_loss: 0.0143 - val_accuracy: 0.6596
# Epoch 90/100
# 54/54 [==============================] - 16s 300ms/step - loss: 0.0086 - accuracy: 0.5565 - val_loss: 0.0145 - val_accuracy: 0.6595
# Epoch 91/100
# 54/54 [==============================] - 16s 300ms/step - loss: 0.0087 - accuracy: 0.5565 - val_loss: 0.0142 - val_accuracy: 0.6596
# Epoch 92/100
# 54/54 [==============================] - 16s 299ms/step - loss: 0.0085 - accuracy: 0.5565 - val_loss: 0.0147 - val_accuracy: 0.6595
# Epoch 93/100
# 54/54 [==============================] - 16s 300ms/step - loss: 0.0085 - accuracy: 0.5565 - val_loss: 0.0142 - val_accuracy: 0.6596
# Epoch 94/100
# 54/54 [==============================] - 16s 300ms/step - loss: 0.0085 - accuracy: 0.5565 - val_loss: 0.0141 - val_accuracy: 0.6597
# Epoch 95/100
# 54/54 [==============================] - 16s 299ms/step - loss: 0.0085 - accuracy: 0.5565 - val_loss: 0.0141 - val_accuracy: 0.6596
# Epoch 96/100
# 54/54 [==============================] - 16s 300ms/step - loss: 0.0084 - accuracy: 0.5565 - val_loss: 0.0139 - val_accuracy: 0.6597
# Epoch 97/100
# 54/54 [==============================] - 16s 302ms/step - loss: 0.0084 - accuracy: 0.5566 - val_loss: 0.0141 - val_accuracy: 0.6598
# Epoch 98/100
# 54/54 [==============================] - 16s 300ms/step - loss: 0.0083 - accuracy: 0.5566 - val_loss: 0.0141 - val_accuracy: 0.6596
# Epoch 99/100
# 54/54 [==============================] - 16s 303ms/step - loss: 0.0083 - accuracy: 0.5566 - val_loss: 0.0138 - val_accuracy: 0.6599
# Epoch 100/100
# 54/54 [==============================] - 16s 302ms/step - loss: 0.0083 - accuracy: 0.5566 - val_loss: 0.0138 - val_accuracy: 0.6598

# %%
# Check how loss & mae went down
epoch_loss = Model_4.history['loss']
epoch_val_loss = Model_4.history['val_loss']
epoch_accuracy = Model_4.history['accuracy']
epoch_val_accuracy = Model_4.history['val_accuracy']

plt.figure(figsize=(20,6))
plt.subplot(1,2,1)
plt.plot(range(0,len(epoch_loss)), epoch_loss, 'b-', linewidth=2, label='Train Loss')
plt.plot(range(0,len(epoch_val_loss)), epoch_val_loss, 'r-', linewidth=2, label='Val Loss')
plt.title('Evolution of loss on train & validation datasets over epochs')
plt.legend(loc='best')
plt.subplot(1,2,2)
plt.plot(range(0,len(epoch_accuracy)), epoch_accuracy, 'g-', linewidth=2, label='Train accuracy')
plt.plot(range(0,len(epoch_val_accuracy)), epoch_val_accuracy, 'y-', linewidth=2, label='Val accuracy')
plt.title('Evolution of accuracy on train & validation datasets over epochs')
plt.legend(loc='best')


plt.show()

# %%
output_test = AutoEncoder.predict(test, batch_size=16)

# %%
plt.figure(figsize=(15,25))
for i in range(0,8,2):
    plt.subplot(4,2,i+1)
    plt.imshow(test[i][:,:,0], cmap='gray')
    
    plt.subplot(4,2,i+2)
    plt.imshow(output_test[i][:,:,0], cmap='gray')

plt.show()
