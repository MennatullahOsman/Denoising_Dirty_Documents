# %% [markdown]
# <a href="https://colab.research.google.com/github/MennatullahOsman/Denoising_Dirty_Documents/blob/main/Model_1_augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount = True)
# Out:
# Mounted at /content/drive

# %%
from tensorflow.keras.layers import Conv2D,MaxPooling2D,UpSampling2D
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from keras.optimizers import SGD
import matplotlib.pyplot as plt
import tensorflow as tf
import pickle
import os

# %%
os.chdir('/content/drive/My Drive/denoising-dirty-documents/pickle_data')

pickle_out = open("x_train_aug.pickle", "rb")
x_train_aug = pickle.load(pickle_out)
pickle_out.close()

pickle_out = open("y_train_aug.pickle", "rb") 
y_train_aug = pickle.load(pickle_out)
pickle_out.close()

pickle_out = open("x_val.pickle", "rb")
x_val = pickle.load(pickle_out)
pickle_out.close()

pickle_out = open("y_val.pickle", "rb")
y_val = pickle.load(pickle_out)
pickle_out.close()

pickle_out = open("test.pickle", "rb")
test = pickle.load(pickle_out)
pickle_out.close()

# %%
tf.keras.backend.clear_session()

input_layer = tf.keras.Input(shape=(420, 540, 1))

#Encoder
x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_layer) 
x = MaxPooling2D((2, 2), padding='same')(x)

#Decoder
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x) 
x = UpSampling2D((2, 2))(x)

output_layer = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

AutoEncoder = tf.keras.Model(input_layer, output_layer)

opt = SGD(lr=1e-2 ,momentum = 0.9 , decay  = 1e-2/100)

AutoEncoder.compile(optimizer=opt, loss='mse', metrics ='accuracy')

AutoEncoder.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 420, 540, 1)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 420, 540, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 210, 270, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 210, 270, 32)      9248
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 420, 540, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 420, 540, 1)       289
# =================================================================
# Total params: 9,857
# Trainable params: 9,857
# Non-trainable params: 0
# _________________________________________________________________

# %%
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20)
Model_1_augmentation = AutoEncoder.fit(x_train_aug , y_train_aug ,epochs= 100, batch_size=30,validation_data=(x_val,y_val),  callbacks=[earlystop])
# Out:
# Epoch 1/100
# 54/54 [==============================] - 12s 230ms/step - loss: 0.0965 - accuracy: 0.4510 - val_loss: 0.0646 - val_accuracy: 0.6411
# Epoch 2/100
# 54/54 [==============================] - 12s 216ms/step - loss: 0.0641 - accuracy: 0.5114 - val_loss: 0.0622 - val_accuracy: 0.6411
# Epoch 3/100
# 54/54 [==============================] - 12s 218ms/step - loss: 0.0598 - accuracy: 0.5484 - val_loss: 0.0596 - val_accuracy: 0.6411
# Epoch 4/100
# 54/54 [==============================] - 12s 218ms/step - loss: 0.0548 - accuracy: 0.5499 - val_loss: 0.0559 - val_accuracy: 0.6410
# Epoch 5/100
# 54/54 [==============================] - 12s 222ms/step - loss: 0.0487 - accuracy: 0.5503 - val_loss: 0.0509 - val_accuracy: 0.6402
# Epoch 6/100
# 54/54 [==============================] - 12s 220ms/step - loss: 0.0413 - accuracy: 0.5496 - val_loss: 0.0448 - val_accuracy: 0.6406
# Epoch 7/100
# 54/54 [==============================] - 12s 222ms/step - loss: 0.0336 - accuracy: 0.5489 - val_loss: 0.0389 - val_accuracy: 0.6435
# Epoch 8/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.0279 - accuracy: 0.5494 - val_loss: 0.0348 - val_accuracy: 0.6465
# Epoch 9/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.0244 - accuracy: 0.5499 - val_loss: 0.0318 - val_accuracy: 0.6485
# Epoch 10/100
# 54/54 [==============================] - 12s 225ms/step - loss: 0.0221 - accuracy: 0.5504 - val_loss: 0.0295 - val_accuracy: 0.6500
# Epoch 11/100
# 54/54 [==============================] - 12s 225ms/step - loss: 0.0203 - accuracy: 0.5510 - val_loss: 0.0277 - val_accuracy: 0.6514
# Epoch 12/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0188 - accuracy: 0.5515 - val_loss: 0.0260 - val_accuracy: 0.6524
# Epoch 13/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0176 - accuracy: 0.5520 - val_loss: 0.0246 - val_accuracy: 0.6534
# Epoch 14/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.0166 - accuracy: 0.5526 - val_loss: 0.0233 - val_accuracy: 0.6543
# Epoch 15/100
# 54/54 [==============================] - 12s 222ms/step - loss: 0.0157 - accuracy: 0.5531 - val_loss: 0.0223 - val_accuracy: 0.6550
# Epoch 16/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0149 - accuracy: 0.5535 - val_loss: 0.0212 - val_accuracy: 0.6558
# Epoch 17/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0142 - accuracy: 0.5540 - val_loss: 0.0209 - val_accuracy: 0.6563
# Epoch 18/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0135 - accuracy: 0.5543 - val_loss: 0.0200 - val_accuracy: 0.6569
# Epoch 19/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0130 - accuracy: 0.5546 - val_loss: 0.0190 - val_accuracy: 0.6574
# Epoch 20/100
# 54/54 [==============================] - 12s 225ms/step - loss: 0.0125 - accuracy: 0.5549 - val_loss: 0.0186 - val_accuracy: 0.6577
# Epoch 21/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0121 - accuracy: 0.5551 - val_loss: 0.0181 - val_accuracy: 0.6581
# Epoch 22/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.0117 - accuracy: 0.5553 - val_loss: 0.0175 - val_accuracy: 0.6584
# Epoch 23/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.0114 - accuracy: 0.5555 - val_loss: 0.0169 - val_accuracy: 0.6587
# Epoch 24/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0110 - accuracy: 0.5556 - val_loss: 0.0166 - val_accuracy: 0.6590
# Epoch 25/100
# 54/54 [==============================] - 12s 225ms/step - loss: 0.0107 - accuracy: 0.5558 - val_loss: 0.0161 - val_accuracy: 0.6592
# Epoch 26/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0105 - accuracy: 0.5559 - val_loss: 0.0160 - val_accuracy: 0.6593
# Epoch 27/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0102 - accuracy: 0.5559 - val_loss: 0.0153 - val_accuracy: 0.6596
# Epoch 28/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0100 - accuracy: 0.5560 - val_loss: 0.0150 - val_accuracy: 0.6597
# Epoch 29/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.0098 - accuracy: 0.5561 - val_loss: 0.0155 - val_accuracy: 0.6596
# Epoch 30/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0096 - accuracy: 0.5561 - val_loss: 0.0148 - val_accuracy: 0.6598
# Epoch 31/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.0095 - accuracy: 0.5562 - val_loss: 0.0145 - val_accuracy: 0.6599
# Epoch 32/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.0093 - accuracy: 0.5562 - val_loss: 0.0145 - val_accuracy: 0.6599
# Epoch 33/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.0092 - accuracy: 0.5562 - val_loss: 0.0142 - val_accuracy: 0.6600
# Epoch 34/100
# 54/54 [==============================] - 12s 225ms/step - loss: 0.0091 - accuracy: 0.5563 - val_loss: 0.0140 - val_accuracy: 0.6601
# Epoch 35/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0090 - accuracy: 0.5563 - val_loss: 0.0141 - val_accuracy: 0.6600
# Epoch 36/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0089 - accuracy: 0.5563 - val_loss: 0.0139 - val_accuracy: 0.6601
# Epoch 37/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0088 - accuracy: 0.5563 - val_loss: 0.0139 - val_accuracy: 0.6601
# Epoch 38/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0087 - accuracy: 0.5564 - val_loss: 0.0137 - val_accuracy: 0.6602
# Epoch 39/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.0086 - accuracy: 0.5564 - val_loss: 0.0133 - val_accuracy: 0.6603
# Epoch 40/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.0085 - accuracy: 0.5564 - val_loss: 0.0131 - val_accuracy: 0.6604
# Epoch 41/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0084 - accuracy: 0.5564 - val_loss: 0.0131 - val_accuracy: 0.6604
# Epoch 42/100
# 54/54 [==============================] - 12s 225ms/step - loss: 0.0083 - accuracy: 0.5565 - val_loss: 0.0128 - val_accuracy: 0.6605
# Epoch 43/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0082 - accuracy: 0.5565 - val_loss: 0.0129 - val_accuracy: 0.6605
# Epoch 44/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0082 - accuracy: 0.5565 - val_loss: 0.0126 - val_accuracy: 0.6605
# Epoch 45/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0081 - accuracy: 0.5565 - val_loss: 0.0126 - val_accuracy: 0.6606
# Epoch 46/100
# 54/54 [==============================] - 12s 222ms/step - loss: 0.0080 - accuracy: 0.5565 - val_loss: 0.0126 - val_accuracy: 0.6606
# Epoch 47/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0079 - accuracy: 0.5566 - val_loss: 0.0125 - val_accuracy: 0.6606
# Epoch 48/100
# 54/54 [==============================] - 12s 225ms/step - loss: 0.0079 - accuracy: 0.5566 - val_loss: 0.0121 - val_accuracy: 0.6607
# Epoch 49/100
# 54/54 [==============================] - 12s 225ms/step - loss: 0.0078 - accuracy: 0.5566 - val_loss: 0.0121 - val_accuracy: 0.6607
# Epoch 50/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0077 - accuracy: 0.5566 - val_loss: 0.0121 - val_accuracy: 0.6607
# Epoch 51/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.0077 - accuracy: 0.5566 - val_loss: 0.0119 - val_accuracy: 0.6608
# Epoch 52/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.0076 - accuracy: 0.5566 - val_loss: 0.0119 - val_accuracy: 0.6608
# Epoch 53/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0075 - accuracy: 0.5566 - val_loss: 0.0116 - val_accuracy: 0.6609
# Epoch 54/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0075 - accuracy: 0.5567 - val_loss: 0.0119 - val_accuracy: 0.6608
# Epoch 55/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0074 - accuracy: 0.5567 - val_loss: 0.0116 - val_accuracy: 0.6609
# Epoch 56/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0074 - accuracy: 0.5567 - val_loss: 0.0116 - val_accuracy: 0.6609
# Epoch 57/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.0073 - accuracy: 0.5567 - val_loss: 0.0114 - val_accuracy: 0.6609
# Epoch 58/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0072 - accuracy: 0.5567 - val_loss: 0.0114 - val_accuracy: 0.6610
# Epoch 59/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0072 - accuracy: 0.5567 - val_loss: 0.0119 - val_accuracy: 0.6608
# Epoch 60/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0071 - accuracy: 0.5567 - val_loss: 0.0112 - val_accuracy: 0.6610
# Epoch 61/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.0071 - accuracy: 0.5568 - val_loss: 0.0111 - val_accuracy: 0.6610
# Epoch 62/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0070 - accuracy: 0.5568 - val_loss: 0.0112 - val_accuracy: 0.6610
# Epoch 63/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0070 - accuracy: 0.5568 - val_loss: 0.0111 - val_accuracy: 0.6610
# Epoch 64/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.0069 - accuracy: 0.5568 - val_loss: 0.0107 - val_accuracy: 0.6611
# Epoch 65/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0069 - accuracy: 0.5568 - val_loss: 0.0111 - val_accuracy: 0.6610
# Epoch 66/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.0068 - accuracy: 0.5568 - val_loss: 0.0107 - val_accuracy: 0.6612
# Epoch 67/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0068 - accuracy: 0.5568 - val_loss: 0.0107 - val_accuracy: 0.6612
# Epoch 68/100
# 54/54 [==============================] - 12s 225ms/step - loss: 0.0067 - accuracy: 0.5568 - val_loss: 0.0106 - val_accuracy: 0.6612
# Epoch 69/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.0067 - accuracy: 0.5568 - val_loss: 0.0106 - val_accuracy: 0.6612
# Epoch 70/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0066 - accuracy: 0.5569 - val_loss: 0.0105 - val_accuracy: 0.6612
# Epoch 71/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0066 - accuracy: 0.5569 - val_loss: 0.0102 - val_accuracy: 0.6613
# Epoch 72/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0065 - accuracy: 0.5569 - val_loss: 0.0103 - val_accuracy: 0.6613
# Epoch 73/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0065 - accuracy: 0.5569 - val_loss: 0.0103 - val_accuracy: 0.6613
# Epoch 74/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.0065 - accuracy: 0.5569 - val_loss: 0.0101 - val_accuracy: 0.6613
# Epoch 75/100
# 54/54 [==============================] - 12s 225ms/step - loss: 0.0064 - accuracy: 0.5569 - val_loss: 0.0101 - val_accuracy: 0.6613
# Epoch 76/100
# 54/54 [==============================] - 12s 225ms/step - loss: 0.0064 - accuracy: 0.5569 - val_loss: 0.0099 - val_accuracy: 0.6614
# Epoch 77/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.0063 - accuracy: 0.5569 - val_loss: 0.0100 - val_accuracy: 0.6614
# Epoch 78/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0063 - accuracy: 0.5569 - val_loss: 0.0099 - val_accuracy: 0.6614
# Epoch 79/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0063 - accuracy: 0.5569 - val_loss: 0.0100 - val_accuracy: 0.6614
# Epoch 80/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0062 - accuracy: 0.5569 - val_loss: 0.0100 - val_accuracy: 0.6614
# Epoch 81/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0062 - accuracy: 0.5569 - val_loss: 0.0101 - val_accuracy: 0.6614
# Epoch 82/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.0062 - accuracy: 0.5570 - val_loss: 0.0099 - val_accuracy: 0.6614
# Epoch 83/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.0061 - accuracy: 0.5570 - val_loss: 0.0098 - val_accuracy: 0.6614
# Epoch 84/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.0061 - accuracy: 0.5570 - val_loss: 0.0098 - val_accuracy: 0.6614
# Epoch 85/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0061 - accuracy: 0.5570 - val_loss: 0.0097 - val_accuracy: 0.6615
# Epoch 86/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.0060 - accuracy: 0.5570 - val_loss: 0.0096 - val_accuracy: 0.6615
# Epoch 87/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.0060 - accuracy: 0.5570 - val_loss: 0.0095 - val_accuracy: 0.6615
# Epoch 88/100
# 54/54 [==============================] - 12s 225ms/step - loss: 0.0060 - accuracy: 0.5570 - val_loss: 0.0096 - val_accuracy: 0.6615
# Epoch 89/100
# 54/54 [==============================] - 12s 225ms/step - loss: 0.0060 - accuracy: 0.5570 - val_loss: 0.0095 - val_accuracy: 0.6615
# Epoch 90/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0059 - accuracy: 0.5570 - val_loss: 0.0096 - val_accuracy: 0.6615
# Epoch 91/100
# 54/54 [==============================] - 12s 225ms/step - loss: 0.0059 - accuracy: 0.5570 - val_loss: 0.0093 - val_accuracy: 0.6616
# Epoch 92/100
# 54/54 [==============================] - 12s 225ms/step - loss: 0.0059 - accuracy: 0.5570 - val_loss: 0.0093 - val_accuracy: 0.6616
# Epoch 93/100
# 54/54 [==============================] - 12s 225ms/step - loss: 0.0058 - accuracy: 0.5570 - val_loss: 0.0095 - val_accuracy: 0.6615
# Epoch 94/100
# 54/54 [==============================] - 12s 225ms/step - loss: 0.0058 - accuracy: 0.5570 - val_loss: 0.0092 - val_accuracy: 0.6616
# Epoch 95/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0058 - accuracy: 0.5570 - val_loss: 0.0092 - val_accuracy: 0.6616
# Epoch 96/100
# 54/54 [==============================] - 12s 225ms/step - loss: 0.0058 - accuracy: 0.5570 - val_loss: 0.0093 - val_accuracy: 0.6616
# Epoch 97/100
# 54/54 [==============================] - 12s 225ms/step - loss: 0.0057 - accuracy: 0.5570 - val_loss: 0.0093 - val_accuracy: 0.6616
# Epoch 98/100
# 54/54 [==============================] - 12s 225ms/step - loss: 0.0057 - accuracy: 0.5570 - val_loss: 0.0090 - val_accuracy: 0.6617
# Epoch 99/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.0057 - accuracy: 0.5570 - val_loss: 0.0091 - val_accuracy: 0.6616
# Epoch 100/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.0057 - accuracy: 0.5570 - val_loss: 0.0088 - val_accuracy: 0.6617

# %%
# Check how loss & mae went down
epoch_loss = Model_1_augmentation.history['loss']
epoch_val_loss = Model_1_augmentation.history['val_loss']
epoch_accuracy = Model_1_augmentation.history['accuracy']
epoch_val_accuracy = Model_1_augmentation.history['val_accuracy']

plt.figure(figsize=(20,6))
plt.subplot(1,2,1)
plt.plot(range(0,len(epoch_loss)), epoch_loss, 'b-', linewidth=2, label='Train Loss')
plt.plot(range(0,len(epoch_val_loss)), epoch_val_loss, 'r-', linewidth=2, label='Val Loss')
plt.title('Evolution of loss on train & validation datasets over epochs')
plt.legend(loc='best')
plt.subplot(1,2,2)
plt.plot(range(0,len(epoch_accuracy)), epoch_accuracy, 'g-', linewidth=2, label='Train accuracy')
plt.plot(range(0,len(epoch_val_accuracy)), epoch_val_accuracy, 'y-', linewidth=2, label='Val accuracy')
plt.title('Evolution of accuracy on train & validation datasets over epochs')
plt.legend(loc='best')


plt.show()

# %%
output_test = AutoEncoder.predict(test, batch_size=16)

# %%
plt.figure(figsize=(15,25))
for i in range(0,8,2):
    plt.subplot(4,2,i+1)
    plt.imshow(test[i][:,:,0], cmap='gray')
    
    plt.subplot(4,2,i+2)
    plt.imshow(output_test[i][:,:,0], cmap='gray')

plt.show()
