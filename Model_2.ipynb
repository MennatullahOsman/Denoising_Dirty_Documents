# %% [markdown]
# <a href="https://colab.research.google.com/github/MennatullahOsman/Denoising_Dirty_Documents/blob/main/Model_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount = True)
# Out:
# Mounted at /content/drive

# %%
from tensorflow.keras.layers import Conv2D,MaxPooling2D,UpSampling2D
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from keras.optimizers import SGD
import matplotlib.pyplot as plt
import tensorflow as tf
import pickle
import os

# %%
os.chdir('/content/drive/My Drive/denoising-dirty-documents/pickle_data')

pickle_out = open("x_train.pickle", "rb")
x_train = pickle.load(pickle_out)
pickle_out.close()

pickle_out = open("y_train.pickle", "rb") 
y_train = pickle.load(pickle_out)
pickle_out.close()

pickle_out = open("x_val.pickle", "rb")
x_val = pickle.load(pickle_out)
pickle_out.close()

pickle_out = open("y_val.pickle", "rb")
y_val = pickle.load(pickle_out)
pickle_out.close()

pickle_out = open("test.pickle", "rb")
test = pickle.load(pickle_out)
pickle_out.close()

# %%
tf.keras.backend.clear_session()

input_layer = tf.keras.Input(shape=(420, 540, 1))

#Encoder
x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_layer) 
x = MaxPooling2D((2, 2), padding='same')(x)

#Decoder
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x) 
x = UpSampling2D((2, 2))(x)

output_layer = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

AutoEncoder = tf.keras.Model(input_layer, output_layer)

AutoEncoder.compile(optimizer='adam', loss='mse', metrics ='accuracy')

AutoEncoder.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 420, 540, 1)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 420, 540, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 210, 270, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 210, 270, 32)      9248
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 420, 540, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 420, 540, 1)       289
# =================================================================
# Total params: 9,857
# Trainable params: 9,857
# Non-trainable params: 0
# _________________________________________________________________

# %%
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20)
Model_2 = AutoEncoder.fit(x_train , y_train ,epochs=100, batch_size=8,validation_data=(x_val,y_val),  callbacks=[earlystop])
# Out:
# Epoch 1/100
# 13/13 [==============================] - 1s 95ms/step - loss: 0.1197 - accuracy: 0.6508 - val_loss: 0.0652 - val_accuracy: 0.6411
# Epoch 2/100
# 13/13 [==============================] - 1s 66ms/step - loss: 0.0667 - accuracy: 0.6509 - val_loss: 0.0673 - val_accuracy: 0.6411
# Epoch 3/100
# 13/13 [==============================] - 1s 66ms/step - loss: 0.0614 - accuracy: 0.6509 - val_loss: 0.0568 - val_accuracy: 0.6411
# Epoch 4/100
# 13/13 [==============================] - 1s 66ms/step - loss: 0.0505 - accuracy: 0.6510 - val_loss: 0.0432 - val_accuracy: 0.6432
# Epoch 5/100
# 13/13 [==============================] - 1s 67ms/step - loss: 0.0361 - accuracy: 0.6562 - val_loss: 0.0281 - val_accuracy: 0.6549
# Epoch 6/100
# 13/13 [==============================] - 1s 67ms/step - loss: 0.0239 - accuracy: 0.6659 - val_loss: 0.0202 - val_accuracy: 0.6579
# Epoch 7/100
# 13/13 [==============================] - 1s 67ms/step - loss: 0.0185 - accuracy: 0.6683 - val_loss: 0.0163 - val_accuracy: 0.6598
# Epoch 8/100
100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0053 - accuracy: 0.6728 - val_loss: 0.0053 - val_accuracy: 0.6625
# Epoch 34/100
# 13/13 [==============================] - 1s 67ms/step - loss: 0.0053 - accuracy: 0.6728 - val_loss: 0.0050 - val_accuracy: 0.6625
# Epoch 35/100
# 13/13 [==============================] - 1s 67ms/step - loss: 0.0051 - accuracy: 0.6728 - val_loss: 0.0050 - val_accuracy: 0.6625
# Epoch 36/100
# 13/13 [==============================] - 1s 67ms/step - loss: 0.0051 - accuracy: 0.6728 - val_loss: 0.0049 - val_accuracy: 0.6625
# Epoch 37/100
# 13/13 [==============================] - 1s 67ms/step - loss: 0.0050 - accuracy: 0.6728 - val_loss: 0.0048 - val_accuracy: 0.6625
# Epoch 38/100
# 13/13 [==============================] - 1s 67ms/step - loss: 0.0049 - accuracy: 0.6728 - val_loss: 0.0047 - val_accuracy: 0.6625
# Epoch 39/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0048 - accuracy: 0.6728 - val_loss: 0.0049 - val_accuracy: 0.6625
# Epoch 40/100
# 13/13 [==============================] - 1s 67ms/step - loss: 0.0048 - accuracy: 0.6728 - val_loss: 0.0046 - val_accuracy: 0.6625
# Epoch 41/100
# 13/13 [==============================] - 1s 67ms/step - loss: 0.0047 - accuracy: 0.6728 - val_loss: 0.0045 - val_accuracy: 0.6625
# Epoch 42/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0046 - accuracy: 0.6728 - val_loss: 0.0047 - val_accuracy: 0.6625
# Epoch 43/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0047 - accuracy: 0.6728 - val_loss: 0.0045 - val_accuracy: 0.6625
# Epoch 44/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0045 - accuracy: 0.6728 - val_loss: 0.0046 - val_accuracy: 0.6625
# Epoch 45/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0046 - accuracy: 0.6728 - val_loss: 0.0043 - val_accuracy: 0.6625
# Epoch 46/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0044 - accuracy: 0.6728 - val_loss: 0.0043 - val_accuracy: 0.6625
# Epoch 47/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0043 - accuracy: 0.6729 - val_loss: 0.0042 - val_accuracy: 0.6625
# Epoch 48/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0043 - accuracy: 0.6729 - val_loss: 0.0041 - val_accuracy: 0.6625
# Epoch 49/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0043 - accuracy: 0.6729 - val_loss: 0.0041 - val_accuracy: 0.6626
# Epoch 50/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0043 - accuracy: 0.6729 - val_loss: 0.0042 - val_accuracy: 0.6626
# Epoch 51/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0042 - accuracy: 0.6729 - val_loss: 0.0040 - val_accuracy: 0.6626
# Epoch 52/100
# 13/13 [==============================] - 1s 67ms/step - loss: 0.0041 - accuracy: 0.6729 - val_loss: 0.0040 - val_accuracy: 0.6626
# Epoch 53/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0041 - accuracy: 0.6729 - val_loss: 0.0039 - val_accuracy: 0.6626
# Epoch 54/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0041 - accuracy: 0.6729 - val_loss: 0.0039 - val_accuracy: 0.6626
# Epoch 55/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0042 - accuracy: 0.6729 - val_loss: 0.0040 - val_accuracy: 0.6626
# Epoch 56/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.
100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0032 - accuracy: 0.6729 - val_loss: 0.0031 - val_accuracy: 0.6626
# Epoch 86/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0031 - accuracy: 0.6729 - val_loss: 0.0031 - val_accuracy: 0.6626
# Epoch 87/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0032 - accuracy: 0.6729 - val_loss: 0.0035 - val_accuracy: 0.6626
# Epoch 88/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0033 - accuracy: 0.6729 - val_loss: 0.0032 - val_accuracy: 0.6626
# Epoch 89/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0031 - accuracy: 0.6729 - val_loss: 0.0030 - val_accuracy: 0.6626
# Epoch 90/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0031 - accuracy: 0.6729 - val_loss: 0.0030 - val_accuracy: 0.6626
# Epoch 91/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0031 - accuracy: 0.6729 - val_loss: 0.0030 - val_accuracy: 0.6626
# Epoch 92/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0031 - accuracy: 0.6729 - val_loss: 0.0030 - val_accuracy: 0.6626
# Epoch 93/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0032 - accuracy: 0.6729 - val_loss: 0.0031 - val_accuracy: 0.6626
# Epoch 94/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0031 - accuracy: 0.6729 - val_loss: 0.0029 - val_accuracy: 0.6626
# Epoch 95/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0030 - accuracy: 0.6729 - val_loss: 0.0029 - val_accuracy: 0.6626
# Epoch 96/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0030 - accuracy: 0.6729 - val_loss: 0.0030 - val_accuracy: 0.6626
# Epoch 97/100
# 13/13 [==============================] - 1s 71ms/step - loss: 0.0030 - accuracy: 0.6729 - val_loss: 0.0030 - val_accuracy: 0.6626
# Epoch 98/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0030 - accuracy: 0.6729 - val_loss: 0.0031 - val_accuracy: 0.6626
# Epoch 99/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0030 - accuracy: 0.6729 - val_loss: 0.0030 - val_accuracy: 0.6626
# Epoch 100/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0030 - accuracy: 0.6729 - val_loss: 0.0029 - val_accuracy: 0.6626

# %%
# Check how loss & mae went down
epoch_loss = Model_2.history['loss']
epoch_val_loss = Model_2.history['val_loss']
epoch_accuracy = Model_2.history['accuracy']
epoch_val_accuracy = Model_2.history['val_accuracy']

plt.figure(figsize=(20,6))
plt.subplot(1,2,1)
plt.plot(range(0,len(epoch_loss)), epoch_loss, 'b-', linewidth=2, label='Train Loss')
plt.plot(range(0,len(epoch_val_loss)), epoch_val_loss, 'r-', linewidth=2, label='Val Loss')
plt.title('Evolution of loss on train & validation datasets over epochs')
plt.legend(loc='best')
plt.subplot(1,2,2)
plt.plot(range(0,len(epoch_accuracy)), epoch_accuracy, 'g-', linewidth=2, label='Train accuracy')
plt.plot(range(0,len(epoch_val_accuracy)), epoch_val_accuracy, 'y-', linewidth=2, label='Val accuracy')
plt.title('Evolution of accuracy on train & validation datasets over epochs')
plt.legend(loc='best')


plt.show()

# %%
output_test = AutoEncoder.predict(test, batch_size=16)

# %%
plt.figure(figsize=(15,25))
for i in range(0,8,2):
    plt.subplot(4,2,i+1)
    plt.imshow(test[i][:,:,0], cmap='gray')
    
    plt.subplot(4,2,i+2)
    plt.imshow(output_test[i][:,:,0], cmap='gray')

plt.show()
